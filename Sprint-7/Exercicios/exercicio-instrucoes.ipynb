# %% [markdown]
# ### Exercício 1 - Contador de Palavras

# %% [markdown]
# ```bash
# # Montar a imagem
# docker build -f Sprint-7/Exercicios/contador-de-palavras/Dockerfile -t contar_palavras .
#
# # -f é o caminho do Dockerfile
# # -t é o nome da imagem
# # . é a raiz do projeto
#
# # Rodar o container baseado na imagem do jupyter/all-spark-notebook
# docker run -p 8888:8888 -it contar-palavras
#
# # Clique na linha no terminal que diz:
# http://127.0.0.1:8888/lab?token=...
#
# # Crie um Terminal ou um arquivo .ipynb no Jupyter Lab
# ```

# %% [markdown]
# #### Rode o código abaixo

# %% [markdown]
# ```python
# from pyspark.sql import SparkSession
#
# spark = SparkSession.builder.appName("ContadorPalavras").getOrCreate()
#
# textFile = spark.sparkContext.textFile("README.md")
#
# words = textFile.flatMap(lambda line: line.split())
#
# counts = words.map(lambda word: (word,1)).reduceByKey(lambda a, b: a + b)
#
# result = counts.collect()
#
# print(result)
#
# ```

# %% [markdown]
# ---
#
# ### Exercício 2 - TMDB

# %% [markdown]
# Execute o código abaixo

# %%
# Testando rapidamente as credenciais e a biblioteca

import requests
import pandas as pd
from IPython.display import display

# Chave API do TMDB
api_key = "36211654b2fd075c9f34f5f7b7827f9e"

# URL de acesso à API para obter os filmes mais bem avaliados
url = f"https://api.themoviedb.org/3/movie/top_rated?api_key={api_key}&amp;language=pt-BR"

# Fazendo a requisição e processando os dados
response = requests.get(url)
data = response.json()
filmes = []

# Iterando sobre os resultados e criando um dicionário para cada filme
for movie in data['results']:
    df = {
        'Titulo': movie['title'],
        'Data de lançamento': movie['release_date'],
        'Visão geral': movie['overview'],
        'Votos': movie['vote_count'],
        'Média de votos': movie['vote_average']
        }
    
    # Adicionando o dicionário ao DataFrame
    filmes.append(df)

# Criando um DataFrame para exibir os dados
df = pd.DataFrame(filmes)
display(df)
# Out:
#                                            Titulo Data de lançamento  \
# 0                        The Shawshank Redemption         1994-09-23
# 1                                   The Godfather         1972-03-14
# 2                           The Godfather Part II         1974-12-20
# 3                                Schindler's List         1993-12-15
# 4                                    12 Angry Men         1957-04-10
# 5                                   Spirited Away         2001-07-20
# 6                                 The Dark Knight         2008-07-16
# 7                     Dilwale Dulhania Le Jayenge         1995-10-20
# 8                                  The Green Mile         1999-12-10
# 9   The Lord of the Rings: The Return of the King         2003-12-17
# 10                                       Parasite         2019-05-30
# 11                                   Pulp Fiction         1994-09-10
# 12                                     Your Name.         2016-08-26
# 13                                   Interstellar         2014-11-05
# 14                 The Good, the Bad and the Ugly         1966-12-23
# 15                                   Forrest Gump         1994-06-23
# 16                                     GoodFellas         1990-09-12
# 17                                  Seven Samurai         1954-04-26
# 18                         Grave of the Fireflies         1988-04-16
# 19                              Life Is Beautiful         1997-12-20
#
#                                           Visão geral  Votos  Média de votos
# 0   Imprisoned in the 1940s for the double murder ...  29860           8.716
# 1   Spanning the years 1945 to 1955, a chronicle o...  22543           8.687
# 2   In the continuing saga of the Corleone crime f...  13647           8.571
# 3   The true story of how businessman Oskar Schind...  17170           8.566
# 4   The defense and the prosecution have rested an...   9795           8.555
# 5   A young girl, Chihiro, becomes trapped in a st...  18023           8.534
# 6   Batman raises the stakes in his war on crime. ...  35279           8.527
# 7   Raj is a rich, carefree, happy-go-lucky second...   4564           8.518
# 8   A supernatural tale set on death row in a Sout...  18919           8.505
# 9   As armies mass for a final battle that will de...  26118           8.494
# 10  All unemployed, Ki-taek's family takes peculia...  20225           8.493
# 11  A burger-loving hit man, his philosophical par...  29784           8.486
# 12  High schoolers Mitsuha and Taki are complete s...  12327           8.479
# 13  The adventures of a group of explorers who mak...  39034           8.468
# 14  While the Civil War rages on between the Union...   9458           8.468
# 15  A man with a low IQ has accomplished great thi...  29331           8.462
# 16  The true story of Henry Hill, a half-Irish, ha...  14080           8.452
# 17  A samurai answers a village's request for prot...   4129           8.450
# 18  In the final months of World War II, 14-year-o...   6386           8.444
# 19  A touching story of an Italian book seller of ...  13828           8.440
